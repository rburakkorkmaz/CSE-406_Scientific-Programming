# %% [markdown]
# <a href="https://colab.research.google.com/github/rburakkorkmaz/CSE-406_Scientific-Programming/blob/main/KorkmazRamazanBurak_E3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><strong>Exercise 3</strong></h1>
# <h1><strong>Student Name & Surname:</strong> Ramazan Burak Korkmaz</h1>
# <h1><strong>Student ID:</strong> 202151056004</h1>

# %%
from collections import Counter
from queue import LifoQueue
import pandas as pd
import random as rnd
import math

# %% [markdown]
# <h1><strong>7) File I/O</strong></h1>

# %% [markdown]
# <h1><strong>Exercise 7.1:</strong> Open a file</h1>
# Write a function that opens a file (input: filename), and prints the file line by line.

# %%
# Open and read all lines from txt file
# All lines will be stored in lines list
with open('example_text.txt') as f:
  lines = f.readlines()

# Now let's print all lines
for line in lines:
  print(line)
# Out:
# My name is Ramazan Burak Korkmaz
#
# This is a example text to show file operations in python
#
# Akdeniz University
#
# Computer Science

# %%
# Another way to do it is by simply taking all information
# inside of txt file and printing it
with open('example_text.txt') as f:
  all_info = f.read()
  print(all_info)
# Out:
# My name is Ramazan Burak Korkmaz
# This is a example text to show file operations in python
# Akdeniz University
# Computer Science

# %% [markdown]
# <h1><strong>Exercise 7.2:</strong> Wordcount</h1>
# On the course website you can find a text file containing the complete works of William Shapespeare.
#
# <ul>
#   <li>(a) Find the 20 most common words</li>
#   <li>(b) How many unique words are used?</li>
#   <li>(c) How many words are used at least 5 times?</li>
#   <li>(d) Write the 200 most common words, and their counts, to a file.</li>
# </ul>

# %%
# Read file
with open('shakespeare.txt') as f:
  all_info = f.read()

# Remove '.', ',' etc.
remove_list = [".", ",", "?", "!", ":", ";"]

for symbol in remove_list:
 all_info = all_info.replace(symbol, "")

# Split string with split() function
lines = all_info.split()

# Use counter package to count number of words
words = Counter(lines)

# Create a pandas dataframe from Counter object.
df_words = pd.DataFrame.from_dict(words, orient='index').reset_index()
df_words.columns = ["Word", "Count"]
df_words.sort_values("Count", ascending=False, inplace=True)

# %% [markdown]
# <h2><strong>Answer (a)</storng><h2>

# %%
print(df_words.head(20).to_string(index=False))
# Out:
# Word  Count
#  the  23407
#    I  20240
#  and  18634
#   to  15873
#   of  15801
#    a  12588
#  you  12011
#   my  10826
#   in   9901
#   is   8298
# that   8061
#  not   8000
#   me   7666
#  And   7440
# with   6812
#   it   6699
#   be   6375
#  his   6315
# your   6016
#  for   5791

# %% [markdown]
# <h2><strong>Answer (b)</storng><h2>

# %%
len(df_words)
# Out:
# 39520

# %% [markdown]
# <h2><strong>Answer (c)</storng><h2>

# %%
len(df_words[df_words["Count"]>5])
# Out:
# 9159

# %% [markdown]
# <h2><strong>Answer (d)</storng><h2>

# %%
with open("most_common_200.txt", 'a') as f:
    df_string = df_words.head(200).to_string(header=False, index=False)
    f.write(df_string)

# %% [markdown]
# <h1><strong>Exercise 7.4:</strong> Sum of lists</h1>
# <ul>
#   <li>(a) Write a function that takes three integers, n, a and b and a filename and writes to the file a list with n random integers between a and b.</li>
#   <li>(b) Write a function that can read the files as generated above and return the values.</li>
#   <li>(c) Write a function that given two filenames (pointing to files as generated by the above function) and an integer k, finds all u and v such that u + v = k, and u is an element of the first list and v is a member of the second list.</li>
#   <li>(d) Test your functions by generating 2 files with n = 2000, a = 1, b = 10000 and k = 5000 and k = 12000.</li>
#   <li>(e) If you are up to a challenge, write a function that solves the sum problem with the restriction that you can only go over every number in the both lists once.</li>
# </ul>

# %% [markdown]
# <h2><strong>Answer (a)</storng><h2>

# %%
def random_number_generator(n, a, b, filename):
  # Let's use list comprehension with randrange function
  random_numbers = [rnd.randrange(a, b, 1) for _ in range(0, n)]
  
  with open(filename + ".txt", "w") as file:
    for number in random_numbers:
      file.write(str(number) + " ")


random_number_generator(10, 5, 100, "deneme")

# %% [markdown]
# <h2><strong>Answer (b)</storng><h2>

# %%
def read_random_number_file(filename):
  with open(filename + ".txt", "r") as file:
    numbers = file.read().split()
    numbers = [int(number) for number in numbers]
  
  # print(numbers)
  return numbers


read_random_number_file("deneme")
# Out:
# [5, 25, 22, 29, 58, 88, 57, 6, 47, 72]

# %% [markdown]
# <h2><strong>Answer (c)</storng><h2>

# %%
def sum_finder(file_1, file_2, k):
  # Empty answer list, that we will return at the end of the function
  answer = []

  # Read files we just created.
  list_1 = read_random_number_file(file_1)
  list_2 = read_random_number_file(file_2)

  # Checking all posibilities between two files
  for u in list_1:
    for v in list_2:
      if u + v == k:
        answer.append((u, v))

  return answer

# %% [markdown]
# <h2><strong>Answer (d)</storng><h2>

# %%
file_1 = "list_1"
file_2 = "list_2"

# Create first and second file
random_number_generator(2000, 1, 10000, file_1)
random_number_generator(2000, 1, 10000, file_2)

# Call the function
print("K = 5000")
print(sum_finder(file_1, file_2, 5000))
print("K = 12000")
print(sum_finder(file_1, file_2, 12000))
# Out:
# K = 5000
# [(640, 4360), (2542, 2458), (1074, 3926), (657, 4343), (3115, 1885), (4440, 560), (3945, 1055), (1439, 3561), (3412, 1588), (3412, 1588), (4100, 900), (2931, 2069), (329, 4671), (4948, 52), (653, 4347), (3478, 1522), (2968, 2032), (2968, 2032), (4094, 906), (4219, 781), (825, 4175), (322, 4678), (862, 4138), (61, 4939), (343, 4657), (1619, 3381), (449, 4551), (3958, 1042), (2234, 2766), (3805, 1195), (1275, 3725), (2016, 2984), (855, 4145), (2257, 2743), (3925, 1075), (2290, 2710), (4397, 603), (4397, 603), (4230, 770), (3939, 1061), (1518, 3482), (539, 4461), (2026, 2974), (3423, 1577), (500, 4500), (1973, 3027), (4170, 830), (4413, 587), (2287, 2713), (198, 4802), (2447, 2553), (1935, 3065), (832, 4168), (3753, 1247), (3945, 1055), (2677, 2323), (703, 4297), (1006, 3994), (4088, 912), (832, 4168), (1959, 3041), (1959, 3041), (4102, 898), (112, 4888), (857, 4143), (4170, 830), (2424, 2576), (1664, 3336), (3958, 1042), (1513, 3487), (632, 4368), (1212, 3788), (2364, 2636), (4934, 66), (2153, 2847), (3712, 1288), (108, 4892), (4115, 885), (3613, 1387), (3613, 1387), (3072, 1928), (2431, 2569), (4899, 101), (3448, 1552), (2971, 2029), (2842, 2158), (3465, 1535), (3336, 1664), (830, 4170), (2424, 2576), (2971, 2029), (785, 4215), (1918, 3082), (3605, 1395), (1170, 3830), (1170, 3830), (574, 4426), (632, 4368), (4546, 454), (3873, 1127), (2546, 2454), (3207, 1793), (3477, 1523), (697, 4303), (2706, 2294), (863, 4137), (2444, 2556), (4697, 303), (1744, 3256), (3017, 1983), (3082, 1918), (4788, 212), (3247, 1753), (4566, 434), (606, 4394), (3830, 1170), (4092, 908), (3573, 1427), (3727, 1273), (472, 4528), (472, 4528), (3613, 1387), (3613, 1387), (3004, 1996), (3905, 1095), (2081, 2919), (2081, 2919), (2070, 2930), (3490, 1510), (3055, 1945), (3055, 1945), (3019, 1981), (2424, 2576), (2454, 2546), (2677, 2323), (190, 4810), (2886, 2114), (3960, 1040), (2249, 2751), (3982, 1018), (3080, 1920), (4654, 346), (1513, 3487), (4570, 430), (2701, 2299), (3831, 1169), (950, 4050), (3704, 1296), (3704, 1296), (1211, 3789), (1557, 3443), (337, 4663), (691, 4309), (3055, 1945), (3055, 1945), (4914, 86), (4651, 349), (4627, 373), (1912, 3088), (4310, 690), (386, 4614), (4285, 715), (4560, 440), (1322, 3678), (803, 4197), (2371, 2629), (1466, 3534), (4716, 284), (3826, 1174), (604, 4396), (3638, 1362), (1916, 3084), (4934, 66), (3244, 1756), (1314, 3686), (3966, 1034), (1246, 3754), (1854, 3146), (2244, 2756), (2568, 2432), (4570, 430), (2354, 2646), (1733, 3267), (1211, 3789), (1275, 3725), (3244, 1756), (3990, 1010), (1058, 3942), (12, 4988), (3452, 1548), (1851, 3149), (3557, 1443), (2435, 2565), (3816, 1184), (4344, 656), (1703, 3297), (950, 4050), (2345, 2655), (2240, 2760), (4485, 515), (4485, 515), (2573, 2427), (4823, 177), (1177, 3823), (3772, 1228), (666, 4334), (1413, 3587), (4306, 694), (4272, 728)]
# K = 12000
# [(2716, 9284), (7433, 4567), (2542, 9458), (7974, 4026), (3303, 8697), (9467, 2533), (7122, 4878), (4114, 7886), (2124, 9876), (3299, 8701), (6655, 5345), (6409, 5591), (9729, 2271), (2658, 9342), (9702, 2298), (4365, 7635), (4365, 7635), (8523, 3477), (6658, 5342), (7258, 4742), (3478, 8522), (7263, 4737), (6766, 5234), (7151, 4849), (9709, 2291), (8114, 3886), (2905, 9095), (2905, 9095), (7785, 4215), (6352, 5648), (9439, 2561), (3342, 8658), (7108, 4892), (4022, 7978), (5924, 6076), (5924, 6076), (7117, 4883), (4083, 7917), (4083, 7917), (3958, 8042), (2892, 9108), (2892, 9108), (4628, 7372), (8970, 3030), (9475, 2525), (6512, 5488), (4327, 7673), (7539, 4461), (4982, 7018), (9111, 2889), (8180, 3820), (8677, 3323), (9540, 2460), (9510, 2490), (9510, 2490), (5459, 6541), (9465, 2535), (2290, 9710), (4707, 7293), (4495, 7505), (4495, 7505), (3644, 8356), (9140, 2860), (4496, 7504), (3249, 8751), (8291, 3709), (8291, 3709), (2197, 9803), (6956, 5044), (9445, 2555), (7225, 4775), (9314, 2686), (7099, 4901), (6886, 5114), (8752, 3248), (6453, 5547), (4210, 7790), (9946, 2054), (3449, 8551), (4089, 7911), (4089, 7911), (2900, 9100), (2900, 9100), (4573, 7427), (2187, 9813), (9272, 2728), (5089, 6911), (5368, 6632), (6921, 5079), (8291, 3709), (8291, 3709), (4557, 7443), (9464, 2536), (7360, 4640), (8626, 3374), (6495, 5505), (8507, 3493), (8507, 3493), (3958, 8042), (8514, 3486), (3975, 8025), (2688, 9312), (9669, 2331), (4185, 7815), (4934, 7066), (3034, 8966), (3034, 8966), (2153, 9847), (5957, 6043), (9275, 2725), (5914, 6086), (3712, 8288), (4115, 7885), (3736, 8264), (3736, 8264), (9775, 2225), (4254, 7746), (6486, 5514), (6267, 5733), (4957, 7043), (3112, 8888), (4574, 7426), (5217, 6783), (7961, 4039), (4355, 7645), (3299, 8701), (4499, 7501), (8896, 3104), (8896, 3104), (3255, 8745), (2329, 9671), (8157, 3843), (3336, 8664), (6803, 5197), (6950, 5050), (6950, 5050), (5050, 6950), (9723, 2277), (9723, 2277), (9101, 2899), (6646, 5354), (4317, 7683), (3661, 8339), (3394, 8606), (4865, 7135), (4232, 7768), (2721, 9279), (8648, 3352), (7189, 4811), (6648, 5352), (7731, 4269), (7451, 4549), (6512, 5488), (5816, 6184), (3605, 8395), (9029, 2971), (7922, 4078), (7922, 4078), (2457, 9543), (7360, 4640), (6786, 5214), (5117, 6883), (3394, 8606), (7806, 4194), (3861, 8139), (6322, 5678), (4037, 7963), (7322, 4678), (2641, 9359), (4866, 7134), (2838, 9162), (4355, 7645), (3959, 8041), (7603, 4397), (8713, 3287), (6042, 5958), (8314, 3686), (8936, 3064), (4783, 7217), (6887, 5113), (3247, 8753), (3205, 8795), (4137, 7863), (6633, 5367), (6598, 5402), (5964, 6036), (4943, 7057), (5873, 6127), (9524, 2476), (3564, 8436), (4871, 7129), (5585, 6415), (6804, 5196), (6804, 5196), (3339, 8661), (3339, 8661), (4924, 7076), (4514, 7486), (2058, 9942), (3573, 8427), (3181, 8819), (3181, 8819), (7122, 4878), (8540, 3460), (2595, 9405), (3727, 8273), (5557, 6443), (8084, 3916), (6267, 5733), (8475, 3525), (2454, 9546), (4628, 7372), (5144, 6856), (5144, 6856), (8180, 3820), (2886, 9114), (7496, 4504), (7487, 4513), (4654, 7346), (5627, 6373), (7647, 4353), (8246, 3754), (3965, 8035), (3554, 8446), (3554, 8446), (4495, 7505), (4495, 7505), (8981, 3019), (5335, 6665), (7116, 4884), (7784, 4216), (7398, 4602), (5835, 6165), (4564, 7436), (5151, 6849), (3471, 8529), (5540, 6460), (5417, 6583), (3788, 8212), (5106, 6894), (2096, 9904), (2096, 9904), (5069, 6931), (5069, 6931), (7604, 4396), (2055, 9945), (7302, 4698), (7302, 4698), (6118, 5882), (6928, 5072), (8157, 3843), (7590, 4410), (7535, 4465), (7535, 4465), (4825, 7175), (4560, 7440), (7855, 4145), (8916, 3084), (3823, 8177), (5809, 6191), (5809, 6191), (5809, 6191), (4027, 7973), (8795, 3205), (8795, 3205), (7237, 4763), (7657, 4343), (4934, 7066), (9475, 2525), (7997, 4003), (7997, 4003), (4510, 7490), (4090, 7910), (4213, 7787), (3566, 8434), (3566, 8434), (3507, 8493), (5446, 6554), (5446, 6554), (2716, 9284), (3966, 8034), (5637, 6363), (2580, 9420), (2580, 9420), (5881, 6119), (6905, 50 ...

# %% [markdown]
# <h2><strong>Answer (e)</storng><h2>

# %%
def modified_sum_finder(file_1, file_2, k):
  # Empty answer list, that we will return at the end of the function
  answer = []

  # Read files we just created.
  list_1 = read_random_number_file(file_1)
  list_2 = read_random_number_file(file_2)

  # Checking all posibilities between two files
  for u in list_1:
    for v in list_2:
      if u + v == k and not ((u,v) in answer or (v,u) in answer):
        answer.append((u, v))

  return answer

# %%
file_1 = "list_1"
file_2 = "list_2"

# Create first and second file
random_number_generator(2000, 1, 10000, file_1)
random_number_generator(2000, 1, 10000, file_2)

# Call the function
print("K = 5000 without modified function")
print(sum_finder(file_1, file_2, 5000))
print("K = 5000 with modified function")
print(modified_sum_finder(file_1, file_2, 5000))
print("K = 12000 without modified function")
print(sum_finder(file_1, file_2, 12000))
print("K = 12000 with modified function")
print(modified_sum_finder(file_1, file_2, 12000))
# Out:
# K = 5000 without modified function
# [(1621, 3379), (3166, 1834), (4112, 888), (2230, 2770), (2230, 2770), (3024, 1976), (3423, 1577), (3816, 1184), (4211, 789), (265, 4735), (4882, 118), (1553, 3447), (501, 4499), (4562, 438), (240, 4760), (763, 4237), (3636, 1364), (4950, 50), (1176, 3824), (3945, 1055), (4623, 377), (1918, 3082), (3895, 1105), (1036, 3964), (3384, 1616), (4854, 146), (3319, 1681), (4639, 361), (3328, 1672), (3328, 1672), (344, 4656), (2010, 2990), (2010, 2990), (1564, 3436), (2245, 2755), (2245, 2755), (1309, 3691), (2739, 2261), (3705, 1295), (307, 4693), (3233, 1767), (3313, 1687), (652, 4348), (652, 4348), (94, 4906), (2253, 2747), (499, 4501), (499, 4501), (1951, 3049), (33, 4967), (4182, 818), (326, 4674), (181, 4819), (2480, 2520), (795, 4205), (3153, 1847), (3153, 1847), (2263, 2737), (1209, 3791), (4525, 475), (2520, 2480), (3707, 1293), (4954, 46), (816, 4184), (2877, 2123), (3663, 1337), (2716, 2284), (2716, 2284), (571, 4429), (4842, 158), (4503, 497), (4910, 90), (4507, 493), (644, 4356), (3700, 1300), (460, 4540), (1067, 3933), (1067, 3933), (566, 4434), (762, 4238), (762, 4238), (2845, 2155), (1426, 3574), (1175, 3825), (2918, 2082), (1050, 3950), (44, 4956), (2562, 2438), (2562, 2438), (3068, 1932), (162, 4838), (3556, 1444), (2356, 2644), (1017, 3983), (1017, 3983), (581, 4419), (3946, 1054), (969, 4031), (3901, 1099), (4223, 777), (1340, 3660), (852, 4148), (852, 4148), (985, 4015), (4503, 497), (4510, 490), (1951, 3049), (438, 4562), (4860, 140), (4581, 419), (1410, 3590), (4934, 66), (4321, 679), (2395, 2605), (3370, 1630), (4156, 844), (3238, 1762), (4312, 688), (362, 4638), (1258, 3742), (2066, 2934), (1562, 3438), (2996, 2004), (2732, 2268), (4588, 412), (4588, 412), (4588, 412), (1193, 3807), (3350, 1650), (3350, 1650), (671, 4329), (4142, 858), (4928, 72), (806, 4194), (4509, 491), (1293, 3707), (3441, 1559), (94, 4906), (137, 4863), (3093, 1907), (4506, 494), (1929, 3071), (4431, 569), (4279, 721), (1508, 3492), (4084, 916), (3262, 1738), (4203, 797), (2022, 2978), (2022, 2978), (2022, 2978), (1684, 3316), (3749, 1251), (3749, 1251), (4766, 234), (3811, 1189), (3063, 1937), (2298, 2702), (4297, 703), (4297, 703), (3972, 1028), (1638, 3362), (2933, 2067), (2789, 2211), (3389, 1611), (1426, 3574), (1668, 3332), (3238, 1762), (74, 4926), (1924, 3076), (4031, 969), (1719, 3281), (3901, 1099), (3556, 1444), (1253, 3747), (4361, 639), (3711, 1289), (1728, 3272), (2763, 2237), (4297, 703), (4297, 703), (3970, 1030), (679, 4321), (1790, 3210), (3914, 1086), (2430, 2570), (2210, 2790), (3102, 1898), (3115, 1885), (3893, 1107), (1496, 3504), (4995, 5), (4842, 158), (4211, 789)]
# K = 5000 with modified function
# [(1621, 3379), (3166, 1834), (4112, 888), (2230, 2770), (3024, 1976), (3423, 1577), (3816, 1184), (4211, 789), (265, 4735), (4882, 118), (1553, 3447), (501, 4499), (4562, 438), (240, 4760), (763, 4237), (3636, 1364), (4950, 50), (1176, 3824), (3945, 1055), (4623, 377), (1918, 3082), (3895, 1105), (1036, 3964), (3384, 1616), (4854, 146), (3319, 1681), (4639, 361), (3328, 1672), (344, 4656), (2010, 2990), (1564, 3436), (2245, 2755), (1309, 3691), (2739, 2261), (3705, 1295), (307, 4693), (3233, 1767), (3313, 1687), (652, 4348), (94, 4906), (2253, 2747), (499, 4501), (1951, 3049), (33, 4967), (4182, 818), (326, 4674), (181, 4819), (2480, 2520), (795, 4205), (3153, 1847), (2263, 2737), (1209, 3791), (4525, 475), (3707, 1293), (4954, 46), (816, 4184), (2877, 2123), (3663, 1337), (2716, 2284), (571, 4429), (4842, 158), (4503, 497), (4910, 90), (4507, 493), (644, 4356), (3700, 1300), (460, 4540), (1067, 3933), (566, 4434), (762, 4238), (2845, 2155), (1426, 3574), (1175, 3825), (2918, 2082), (1050, 3950), (44, 4956), (2562, 2438), (3068, 1932), (162, 4838), (3556, 1444), (2356, 2644), (1017, 3983), (581, 4419), (3946, 1054), (969, 4031), (3901, 1099), (4223, 777), (1340, 3660), (852, 4148), (985, 4015), (4510, 490), (4860, 140), (4581, 419), (1410, 3590), (4934, 66), (4321, 679), (2395, 2605), (3370, 1630), (4156, 844), (3238, 1762), (4312, 688), (362, 4638), (1258, 3742), (2066, 2934), (1562, 3438), (2996, 2004), (2732, 2268), (4588, 412), (1193, 3807), (3350, 1650), (671, 4329), (4142, 858), (4928, 72), (806, 4194), (4509, 491), (3441, 1559), (137, 4863), (3093, 1907), (4506, 494), (1929, 3071), (4431, 569), (4279, 721), (1508, 3492), (4084, 916), (3262, 1738), (4203, 797), (2022, 2978), (1684, 3316), (3749, 1251), (4766, 234), (3811, 1189), (3063, 1937), (2298, 2702), (4297, 703), (3972, 1028), (1638, 3362), (2933, 2067), (2789, 2211), (3389, 1611), (1668, 3332), (74, 4926), (1924, 3076), (1719, 3281), (1253, 3747), (4361, 639), (3711, 1289), (1728, 3272), (2763, 2237), (3970, 1030), (1790, 3210), (3914, 1086), (2430, 2570), (2210, 2790), (3102, 1898), (3115, 1885), (3893, 1107), (1496, 3504), (4995, 5)]
# K = 12000 without modified function
# [(9623, 2377), (9294, 2706), (9294, 2706), (2079, 9921), (2468, 9532), (3994, 8006), (4322, 7678), (9086, 2914), (2546, 9454), (2293, 9707), (2440, 9560), (5983, 6017), (2352, 9648), (5623, 6377), (9918, 2082), (5077, 6923), (4211, 7789), (6499, 5501), (6182, 5818), (7536, 4464), (5367, 6633), (3301, 8699), (6589, 5411), (4423, 7577), (3308, 8692), (2041, 9959), (9001, 2999), (9001, 2999), (4950, 7050), (7499, 4501), (7499, 4501), (3369, 8631), (7637, 4363), (8166, 3834), (8322, 3678), (7286, 4714), (7745, 4255), (9634, 2366), (3499, 8501), (6640, 5360), (6441, 5559), (5812, 6188), (3867, 8133), (5933, 6067), (9788, 2212), (4639, 7361), (8740, 3260), (5997, 6003), (8192, 3808), (8192, 3808), (2962, 9038), (7111, 4889), (5202, 6798), (3237, 8763), (3237, 8763), (5242, 6758), (2823, 9177), (7403, 4597), (7805, 4195), (5421, 6579), (6834, 5166), (8518, 3482), (7671, 4329), (6125, 5875), (7216, 4784), (2253, 9747), (3921, 8079), (3206, 8794), (4235, 7765), (2548, 9452), (9401, 2599), (6257, 5743), (9946, 2054), (6132, 5868), (5628, 6372), (4253, 7747), (4820, 7180), (5189, 6811), (5189, 6811), (4320, 7680), (6142, 5858), (7762, 4238), (7762, 4238), (2949, 9051), (6549, 5451), (2262, 9738), (9141, 2859), (2095, 9905), (8760, 3240), (4954, 7046), (9219, 2781), (8714, 3286), (3861, 8139), (3861, 8139), (4694, 7306), (9480, 2520), (6023, 5977), (3266, 8734), (3266, 8734), (7985, 4015), (5809, 6191), (4503, 7497), (2313, 9687), (9059, 2941), (5507, 6493), (7404, 4596), (8015, 3985), (9420, 2580), (6132, 5868), (2275, 9725), (2275, 9725), (2826, 9174), (2972, 9028), (6142, 5858), (3554, 8446), (7733, 4267), (7699, 4301), (2262, 9738), (6280, 5720), (5096, 6904), (4994, 7006), (8982, 3018), (2569, 9431), (2904, 9096), (2445, 9555), (5817, 6183), (9154, 2846), (8136, 3864), (4763, 7237), (4393, 7607), (3800, 8200), (8609, 3391), (8609, 3391), (4442, 7558), (3800, 8200), (7671, 4329), (7265, 4735), (7760, 4240), (7908, 4092), (2188, 9812), (3724, 8276), (9928, 2072), (6390, 5610), (6390, 5610), (5109, 6891), (2762, 9238), (3901, 8099), (9306, 2694), (6278, 5722), (4325, 7675), (4262, 7738), (4223, 7777), (9664, 2336), (8402, 3598), (9543, 2457), (9543, 2457), (6575, 5425), (9155, 2845), (9712, 2288), (6498, 5502), (4503, 7497), (6360, 5640), (2276, 9724), (2276, 9724), (9201, 2799), (4808, 7192), (2546, 9454), (7398, 4602), (4860, 7140), (3154, 8846), (2058, 9942), (6229, 5771), (9516, 2484), (9516, 2484), (9395, 2605), (5424, 6576), (6320, 5680), (5889, 6111), (6549, 5451), (9971, 2029), (7240, 4760), (2867, 9133), (5420, 6580), (4098, 7902), (6291, 5709), (2066, 9934), (3550, 8450), (5380, 6620), (3394, 8606), (3247, 8753), (3305, 8695), (3092, 8908), (5593, 6407), (2972, 9028), (4557, 7443), (4334, 7666), (5120, 6880), (8869, 3131), (8869, 3131), (6873, 5127), (7039, 4961), (5730, 6270), (3013, 8987), (4928, 7072), (8531, 3469), (3736, 8264), (5809, 6191), (4425, 7575), (6113, 5887), (5646, 6354), (6217, 5783), (5897, 6103), (3095, 8905), (3964, 8036), (4334, 7666), (9880, 2120), (7074, 4926), (9607, 2393), (7033, 4967), (3968, 8032), (5179, 6821), (8242, 3758), (2725, 9275), (9500, 2500), (8684, 3316), (5854, 6146), (3305, 8695), (2439, 9561), (3924, 8076), (2168, 9832), (8621, 3379), (3706, 8294), (3262, 8738), (7568, 4432), (7886, 4114), (4694, 7306), (9865, 2135), (9377, 2623), (8694, 3306), (3749, 8251), (7130, 4870), (5991, 6009), (5507, 6493), (8176, 3824), (3783, 8217), (4281, 7719), (4393, 7607), (9811, 2189), (9764, 2236), (8912, 3088), (6102, 5898), (3748, 8252), (9345, 2655), (7069, 4931), (9474, 2526), (4644, 7356), (3180, 8820), (3180, 8820), (3389, 8611), (7586, 4414), (3631, 8369), (9607, 2393), (9764, 2236), (3933, 8067), (8123, 3877), (8123, 3877), (2636, 9364), (3901, 8099), (8694, 3306), (3890, 8110), (3339, 8661), (8148, 3852), (7319, 4681), (7319, 4681), (6487, 5513), (6795, 5205), (4393, 7607), (3603, 8397), (2636, 9364), (9570, 2430), (2763, 9237), (5859, 6141), (2186, 9814), (8578, 3422), (4299, 7701), (4299, 77 ...
# K = 12000 with modified function
# [(9623, 2377), (9294, 2706), (2079, 9921), (2468, 9532), (3994, 8006), (4322, 7678), (9086, 2914), (2546, 9454), (2293, 9707), (2440, 9560), (5983, 6017), (2352, 9648), (5623, 6377), (9918, 2082), (5077, 6923), (4211, 7789), (6499, 5501), (6182, 5818), (7536, 4464), (5367, 6633), (3301, 8699), (6589, 5411), (4423, 7577), (3308, 8692), (2041, 9959), (9001, 2999), (4950, 7050), (7499, 4501), (3369, 8631), (7637, 4363), (8166, 3834), (8322, 3678), (7286, 4714), (7745, 4255), (9634, 2366), (3499, 8501), (6640, 5360), (6441, 5559), (5812, 6188), (3867, 8133), (5933, 6067), (9788, 2212), (4639, 7361), (8740, 3260), (5997, 6003), (8192, 3808), (2962, 9038), (7111, 4889), (5202, 6798), (3237, 8763), (5242, 6758), (2823, 9177), (7403, 4597), (7805, 4195), (5421, 6579), (6834, 5166), (8518, 3482), (7671, 4329), (6125, 5875), (7216, 4784), (2253, 9747), (3921, 8079), (3206, 8794), (4235, 7765), (2548, 9452), (9401, 2599), (6257, 5743), (9946, 2054), (6132, 5868), (5628, 6372), (4253, 7747), (4820, 7180), (5189, 6811), (4320, 7680), (6142, 5858), (7762, 4238), (2949, 9051), (6549, 5451), (2262, 9738), (9141, 2859), (2095, 9905), (8760, 3240), (4954, 7046), (9219, 2781), (8714, 3286), (3861, 8139), (4694, 7306), (9480, 2520), (6023, 5977), (3266, 8734), (7985, 4015), (5809, 6191), (4503, 7497), (2313, 9687), (9059, 2941), (5507, 6493), (7404, 4596), (8015, 3985), (9420, 2580), (2275, 9725), (2826, 9174), (2972, 9028), (3554, 8446), (7733, 4267), (7699, 4301), (6280, 5720), (5096, 6904), (4994, 7006), (8982, 3018), (2569, 9431), (2904, 9096), (2445, 9555), (5817, 6183), (9154, 2846), (8136, 3864), (4763, 7237), (4393, 7607), (3800, 8200), (8609, 3391), (4442, 7558), (7265, 4735), (7760, 4240), (7908, 4092), (2188, 9812), (3724, 8276), (9928, 2072), (6390, 5610), (5109, 6891), (2762, 9238), (3901, 8099), (9306, 2694), (6278, 5722), (4325, 7675), (4262, 7738), (4223, 7777), (9664, 2336), (8402, 3598), (9543, 2457), (6575, 5425), (9155, 2845), (9712, 2288), (6498, 5502), (6360, 5640), (2276, 9724), (9201, 2799), (4808, 7192), (7398, 4602), (4860, 7140), (3154, 8846), (2058, 9942), (6229, 5771), (9516, 2484), (9395, 2605), (5424, 6576), (6320, 5680), (5889, 6111), (9971, 2029), (7240, 4760), (2867, 9133), (5420, 6580), (4098, 7902), (6291, 5709), (2066, 9934), (3550, 8450), (5380, 6620), (3394, 8606), (3247, 8753), (3305, 8695), (3092, 8908), (5593, 6407), (4557, 7443), (4334, 7666), (5120, 6880), (8869, 3131), (6873, 5127), (7039, 4961), (5730, 6270), (3013, 8987), (4928, 7072), (8531, 3469), (3736, 8264), (4425, 7575), (6113, 5887), (5646, 6354), (6217, 5783), (5897, 6103), (3095, 8905), (3964, 8036), (9880, 2120), (7074, 4926), (9607, 2393), (7033, 4967), (3968, 8032), (5179, 6821), (8242, 3758), (2725, 9275), (9500, 2500), (8684, 3316), (5854, 6146), (2439, 9561), (3924, 8076), (2168, 9832), (8621, 3379), (3706, 8294), (3262, 8738), (7568, 4432), (7886, 4114), (9865, 2135), (9377, 2623), (8694, 3306), (3749, 8251), (7130, 4870), (5991, 6009), (8176, 3824), (3783, 8217), (4281, 7719), (9811, 2189), (9764, 2236), (8912, 3088), (6102, 5898), (3748, 8252), (9345, 2655), (7069, 4931), (9474, 2526), (4644, 7356), (3180, 8820), (3389, 8611), (7586, 4414), (3631, 8369), (3933, 8067), (8123, 3877), (2636, 9364), (3890, 8110), (3339, 8661), (8148, 3852), (7319, 4681), (6487, 5513), (6795, 5205), (3603, 8397), (9570, 2430), (2763, 9237), (5859, 6141), (2186, 9814), (8578, 3422), (4299, 7701), (9751, 2249), (4330, 7670), (8353, 3647), (4738, 7262), (2257, 9743), (3102, 8898), (2512, 9488), (5927, 6073), (3720, 8280), (3893, 8107), (9353, 2647), (7788, 4212), (7816, 4184), (5549, 6451), (5514, 6486), (5622, 6378), (7176, 4824), (8521, 3479), (4695, 7305), (2891, 9109)]

# %% [markdown]
# <h1><strong>8) Classes</strong></h1>

# %% [markdown]
# <h1><strong>Exercise 8.1:</strong> Rational numbers</h1>
#
# <ul>
#   <li>(a) Create a class Rational which is initialized by two integers, p and q, the nominator and denominator</li>
#   <li>(b) Add a method to print the rational number as p/q (the __str__ or __repr__ method is useful).</li>
#   <li>(c)We would like to represent 10/20 by 1/2 instead, hence write a function that computes the greatest common divisor, and ensure that every rational number is simplified</li>
#   <li>(d) Add a method so that we can add two rational numbers with r1 + r2, here the __add__() method is useful.</li>
#   <li>(e) Add a method to subtract two rational numbers. (__sub__)</li>
#   <li>(f) Add a method to multiply two rational numbers. (__mul__)</li>
#   <li>(g) Add a method to divide two rational numbers. (__div__)</li>
#   <li>(h) Add a method that compares whether two rational numbers are equal.</li>
#   <li>(i) Add a method to convert the rational number to a floating point (the __float__() method may be handy).</li>
#   <li>(j) Add any more functionality that you think is useful but I failed to mention.</li>
# </ul>

# %%
# Answer to (a)
class Rational:
  p = None
  q = None
  def __init__(self, p, q) -> None:
    if q == 0:
        raise ValueError('Denominator must not be zero')
    if not isinstance(p, int):
        raise TypeError('Numerator must be an integer')
    if not isinstance(q, int):
        raise TypeError('Denominator must be an integer')

    # Answer to (c)
    common_divisor = math.gcd(p, q)

    self.p = p // common_divisor
    self.q = q // common_divisor


  # Answer to (b)
  def __repr__(self):
      return f"{self.p}/{self.q}"

  def __str__(self):
      return f"{self.p}/{self.q}"

  def __add__(self, r2):
    return Rational(self.p * r2.q + r2.p * self.q, self.q * r2.q)
  
  def __sub__(self, r2):
    return Rational(self.p * r2.q - r2.p * self.q, self.q * r2.q)
  
  def __mul__(self, r2):
    return Rational(self.p * r2.p, self.q * r2.q)
  
  def __truediv__(self, r2):
    return Rational(self.p * r2.q, self.q * r2.p)

  def __eq__(self, r2):
    return self.p == r2.p and self.q == r2.q

  def __float__(self):
    return float(self.p) / float(self.q)

# %% [markdown]
# <h2><strong>Answer (b)</storng><h2>

# %%
r = Rational(3, 10)
print(r)
# Out:
# 3/10

# %% [markdown]
# <h2><strong>Answer (c)</storng><h2>

# %%
r = Rational(10, 20)
print(r)
# Out:
# 1/2

# %% [markdown]
# <h2><strong>Answer (d)</storng><h2>

# %%
r1 = Rational(10, 20)
r2 = Rational(10, 30)

r1 + r2
# Out:
# 5/6

# %% [markdown]
# <h2><strong>Answer (e)</storng><h2>

# %%
r1 = Rational(10, 20)
r2 = Rational(10, 30)

r1 - r2
# Out:
# 1/6

# %% [markdown]
# <h2><strong>Answer (f)</storng><h2>

# %%
r1 = Rational(10, 20)
r2 = Rational(10, 30)

r1 * r2
# Out:
# 1/6

# %% [markdown]
# <h2><strong>Answer (g)</storng><h2>

# %%
r1 = Rational(10, 20)
r2 = Rational(10, 30)

r1 / r2
# Out:
# 3/2

# %% [markdown]
# <h2><strong>Answer (h)</storng><h2>

# %%
r1 = Rational(10, 20)
r2 = Rational(10, 30)

print(r1 == r2)

r1 = Rational(10, 30)
r2 = Rational(10, 30)

print(r1 == r2)
# Out:
# False
# True

# %% [markdown]
# <h2><strong>Answer (i)</storng><h2>

# %%
r1 = Rational(10, 20)
float(r1)
# Out:
# 0.5

# %% [markdown]
# <h1><strong>Exercise 8.2:</strong> Rock Paper Scissors</h1>
# In this problem, we will finish an implementation for Rock-Paper-Scissors. We have written some code to get you started, now it's up to you to nish the implementation.
#
# The code consists of 2 files: game.py and agent.py. The code that implements the actual game is coded in game.py. agent.py defines several agents that can play the game. Download the starter code here using
# <ul>
#   <li>(a) Finish the implementation of game.py by implementing the compare function, updating the scores (where a win is 1 point, and a tie or loss 0 points), and finally the summary function that gives some information after the game.</li>
#   <li>(b) Implement the HumanAgent in agent.py, this agent should query the user for the next move, and ensure that the user gives valid input.</li>
#   <li>(c) Implement MyAgent, where you can implement your own strategy, try to beat the InstructorAgent consistently over 100 rounds.</li>
# </ul>

# %%
'''
Rock-Paper-Scissors game
Starter code for Stanford CME 193
author: Sven Schmit
'''
possible_moves = ['r', 's', 'p']
import random

class Agent:
    def getMove(self, moves_other, moves_self):
        pass


class InstructorAgent(Agent):
    def __init__(self):
        p_rock = random.random()
        p_scissors = random.random()
        p_paper = random.random()
        p_total = p_rock + p_scissors + p_paper

        self.p_rock = p_rock / p_total
        self.p_scissors = self.p_rock + p_scissors / p_total

    def getMove(self, moves_other, moves_self):
        random_move = random.random()
        if random_move < self.p_rock:
            return 'r'
        elif random_move < self.p_scissors:
            return 's'
        else:
            return 'p'


class MyAgent(Agent):
    def getMove(self, moves_other, moves_self):

        # ANSWER (C)
        # Rock- Scissors - Paper is a luck game. There is no place for a stragety
        # So best strategy would be to randomly create moves
        # Same like InstructorAgent does

        random_move = random.random()
        if random_move < self.p_rock:
            return 'r'
        elif random_move < self.p_scissors:
            return 's'
        else:
            return 'p'


class HumanAgent(Agent):
    def getMove(self, moves_other, moves_self):
        user_move = ""
        # ANSWER (B)
        while True:
          user_move = input("r for Rock, s for Scissors, p for Paper")
          if user_move.lower() in possible_moves:
            break
          print("Wrong input. Please enter a valid one")
          user_move = ""
        
        return user_move.lower()

# %%
'''
Rock-Paper-Scissors game
Starter code for Stanford CME 193
author: Sven Schmit
'''

class Game:
    def __init__(self, agent1, agent2):
        self.moves_a1 = []
        self.moves_a2 = []
        self.nround = 0
        self.score_a1 = 0
        self.score_a2 = 0

        self.agent1 = agent1
        self.agent2 = agent2

    def round(self):
        print(f'Round {self.nround+1}: ')
        # we pass along history so a player can take that into account when
        # deciding the next move
        move_a1 = self.agent1.getMove(self.moves_a2, self.moves_a1)
        move_a2 = self.agent2.getMove(self.moves_a1, self.moves_a2)

        # compare the moves and decide who wins
        outcome = self.compare(move_a1, move_a2)

        # output outcome of current round
        if outcome == 1:
            print(f'Player 1 wins: {move_a1} beats {move_a2}')
            self.score_a1 += 1
        elif outcome == 0:
            print(f'This round is tied, both players played {move_a1}')
        else:
            print(f'Player 2 wins: {move_a2} beats {move_a1}')
            self.score_a2 += 1

        # update scores

        # YOUR CODE HERE

        self.moves_a1.append(move_a1)
        self.moves_a2.append(move_a2)

    def play(self, nrounds):
        for r in range(nrounds):
            self.round()
            self.nround += 1

    def summary(self):
        # print some summary of the games
        print('='*20)
        if self.score_a1 > self.score_a2:
            print('Player 1 wins')
        elif self.score_a1 < self.score_a2:
            print('Player 2 wins')
        else:
            print('The game ends in a tie')

        print(f'Final score: {self.score_a1} - {self.score_a2}')

        # To implement: find the move that was played most often
        
        # ANSWER (A)

        print(f'Most played move: {0}')
        print('='*20)

    def compare(self, move1, move2):
        # returns 1 if move1 wins, 0 if it's a tie, and -1 if move2 wins
        

        if move1 not in possible_moves or move2 not in possible_moves:
          raise ValueError("Moves are not valid.")
        # YOUR CODE HERE
        if move1 + move2 == "rs" or move1 + move2 == "sp" or move1 + move2 == "pr":
          return 1
        elif move1 + move2 == "rr" or move1 + move2 == "ss" or move1 + move2 == "pp":
          return 0
        else:
          return -1

# %%
'''
Rock-Paper-Scissors game
Starter code for Stanford CME 193
author: Sven Schmit
'''


# We can specify which agents we want to play the game here
# Optional: pass this in using the command line
game = Game(HumanAgent(), InstructorAgent())

# How many rounds do we want to play
# Optional: pass this in using the command line
number_rounds = 10
game.play(number_rounds)

# Print summary
game.summary()
# Out:
# Round 1:
# r for Rock, s for Scissors, p for Paperr
# Player 2 wins: p beats r
# Round 2:
# r for Rock, s for Scissors, p for Paperr
# This round is tied, both players played r
# Round 3:
# r for Rock, s for Scissors, p for Paperr
# Player 1 wins: r beats s
# Round 4:
# r for Rock, s for Scissors, p for Paperr
# Player 2 wins: p beats r
# Round 5:
# r for Rock, s for Scissors, p for Paperr
# Player 2 wins: p beats r
# Round 6:
# r for Rock, s for Scissors, p for Paperr
# Player 1 wins: r beats s
# Round 7:
# r for Rock, s for Scissors, p for Paperr
# Player 1 wins: r beats s
# Round 8:
# r for Rock, s for Scissors, p for Paperr
# Player 1 wins: r beats s
# Round 9:
# r for Rock, s for Scissors, p for Paperr
# Player 2 wins: p beats r
# Round 10:
# r for Rock, s for Scissors, p for Paperr
# Player 1 wins: r beats s
# ====================
# Player 1 wins
# Final score: 5 - 4
# Most played move: 0
# ====================

# %% [markdown]
# <h1><strong>Exercise 8.4:</strong> Sparse and dense vectors</h1>
# In exercise 6.5 you implemented functions for sparse and dense vector multiplications using lists and dictionaries. However, this is a bit clumsy to use in practice. Really, we would like to represent sparse and dense vectors as classes, this way we can overload operators such as + ( add ) and get sensible
# output. For example, using + on two dense vectors implemented as lists would append the second vector to the first, instead of adding the two together.
#
# Implement sparse and dense vectors. Both classes should have the following capabilities:
#
# <ul>
#   <li>(a) Print vector</li>
#   <li>(b) Add two vectors (both if other is dense and sparse)</li>
#   <li>(c) Multiply two vectors (both if other is dense and sparse)</li>
# </ul>
#
# Do re-use your code from the previous exercise.
# Hint: isinstance() might be useful.

# %%
class DenseVector:
  vector = {}
  def __init__(self, vector):
      self.vector = vector
  
  def __repr__(self):
      return f"{self.vector}" 
  
  def __add__(self, v2):
    temp = {}
    if isinstance(v2, DenseVector):
      for (key, value) in self.vector.items():
        temp[key] = value + v2.vector[key]
    elif isinstance(v2, SparseVector):
      for index, (key, value) in enumerate(self.vector.items()):
        temp[key] = value + v2.vector[index]

    return DenseVector(temp)

  def __mul__(self, v2):
    temp = {}
    if isinstance(v2, DenseVector):
      for key, value in self.vector.items():
        temp[key] = value * v2.vector[key]
    elif isinstance(v2, SparseVector):
      for index, (key, value) in enumerate(self.vector.items()):
        temp[key] = value * v2.vector[index]

    return DenseVector(temp)

# %%
class SparseVector:
  vector = []
  def __init__(self, vector):
      self.vector = vector
  
  def __repr__(self):
      return f"{self.vector}" 
  
  def __add__(self, v2):
    temp = []
    for index, value in enumerate(self.vector):
      temp.append(value + v2.vector[index])

    return SparseVector(temp)

  def __mul__(self, v2):
    temp = []
    for index, value in enumerate(self.vector):
      temp.append(value * v2.vector[index])

    return SparseVector(temp)

# %%
d1 = DenseVector({0: 1, 1: 2, 2: 3})
d2 = DenseVector({0: 5, 1: 4, 2: 3})

s1 = SparseVector([1, 2, 3])
s2 = SparseVector([5, 4, 3])

print("Dense + Dense")
print(d1 + d2)

print("Sparse + Sparse")
print(s1 + s2)

print("Dense + Sparse")
print(d1 + s1)

print("Sparse + Dense")
print(s2 + d2)
# Out:
# Dense + Dense
# {0: 6, 1: 6, 2: 6}
# Sparse + Sparse
# [6, 6, 6]
# Dense + Sparse
# {0: 2, 1: 4, 2: 6}
# Sparse + Dense
# [10, 8, 6]

# %%
print("Dense + Dense")
print(d1 + d2)

print("Sparse + Sparse")
print(s1 + s2)

print("Dense + Sparse")
print(d1 + s1)

print("Sparse + Dense")
print(s2 + d2)
# Out:
# {0: 5, 1: 8, 2: 9}

# %% [markdown]
# <h1><strong>Exercise 8.5:</strong> Implementing the set class</h1>
# Write a class mySet that has the same basic functionality as the Python set data structure. Base your implementation on a dictionary.

# %% [markdown]
# <h1><strong>Exercise 8.6:</strong> Binary search tree</h1>
# In this exercise, we will implement a binary search tree. See http://en.wikipedia.org/wiki/Binary_search_tree for an explanation.
# <ul>
#   <li>(a) Define a class Node, and write the constructor, which takes one argument, value, and initializes
# the left and right children to None.</li>
#   <li>(b) Write a function to print the tree.</li>
#   <li>(c) Write a function that inserts a new value in the tree at the right location.</li>
#   <li>(d) Write a function that looks up a value in the tree.</li>
#   <li>(e) Write a function that removes a value from the tree.</li>
# </ul>

# %%
# ANSWER (A)
class Node:
  l_child = None
  r_child = None
  parent = None
  value = None
  def __init__(self, value):
    self.value = value

class BinarySearchTree:
  def __init__(self, root_value):
    self.root = Node(root_value)

  # ANSWER (B)
  def inorder_print(self, n):
    """ Inorder print function. It uses recursion to print Binary Search Tree """
    if n != None:
      self.inorder_print(n.l_child)
      print(n.value, end=" ")
      self.inorder_print(n.r_child)

  def print_tree(self):
    """ This method is only clean coe purpuse. I did not wanted to 
    insert root as parameter to function. """
    print("Inorder")
    self.inorder_print(self.root)
    print("\n")

  
  def find_value(self, value):
    indicator = self.root

    while True:
      if value == indicator.value:
        return True, indicator
      elif value > indicator.value:
        if indicator.r_child != None:
          indicator = indicator.r_child
        else:
          return False, None
      elif value < indicator.value:
        if indicator.l_child != None:
          indicator = indicator.l_child
        else:
          return False, None

  def insert(self, value):
    indicator = self.root

    while value >= indicator.value:
      if indicator.r_child != None:
        indicator = indicator.r_child
      else:
        indicator.r_child = Node(value)
        indicator.r_child.parent = indicator
        break
    
    while value < indicator.value:
      if indicator.l_child != None:
        indicator = indicator.l_child
      else:
        indicator.l_child = Node(value)
        indicator.l_child.parent = indicator
        break

# %%
bst = BinarySearchTree(5)

# ANSWER (C)
bst.insert(6)
bst.insert(1)
bst.insert(32)
bst.insert(53)
bst.insert(22)
bst.insert(9)

# ANSWER (B)
bst.print_tree()

# ANSWER (D)
is_found, n = bst.find_value(32)
print(f"Is number 32 in the tree: {is_found}")
print(f"If found what are the relative nodes of number 32 node: Left Child: {n.l_child.value}, Right Child: {n.r_child.value}")
is_found, n = bst.find_value(99)
print(f"Is number 99 in the tree: {is_found}")
# Out:
# Inorder
# 1 5 6 9 22 32 53
#
# Is number 32 in the tree: True
# If found what are the relative nodes of number 32 node: Left Child: 22, Right Child: 53
# Is number 99 in the tree: False
